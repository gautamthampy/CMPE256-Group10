# %% [markdown]
# # CMPE 256 - Recommender Systems Project
# ## Data Exploration and Analysis
#
# This notebook explores the dataset and helps understand the data characteristics.

# %%
import sys
sys.path.insert(0, '../src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

from data_loader import DataLoader, print_statistics

# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# %% [markdown]
# ## 1. Load Data

# %%
# Load data
loader = DataLoader('../train-2.txt', seed=42)
user_items = loader.load_data()

# Get statistics
stats = loader.get_statistics()
print_statistics(stats)
